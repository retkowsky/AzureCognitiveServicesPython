# %% [markdown]
# <img src="https://raw.githubusercontent.com/retkowsky/images/master/logo%20azure%20cog%20svcs.jpg">

# %% [markdown]
# Documentation : https://azure.microsoft.com/en-us/services/cognitive-services/

# %% [markdown]
# # Analyse d'image
# > https://azure.microsoft.com/en-us/services/cognitive-services/face/

# %%
import sys
sys.version
# Out:
# '3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31) \n[GCC 7.3.0]'

# %%
import datetime
now = datetime.datetime.now()
print(now)
# Out:
# 2020-07-07 13:45:30.047756

# %% [markdown]
# ## Paramétrage

# %%
import requests
# If you are using a Jupyter notebook, uncomment the following line.
#%matplotlib inline
import matplotlib.pyplot as plt
import json
from PIL import Image
from io import BytesIO

# %%
subscription_key = "AREMPLACER"
assert subscription_key

# %%
vision_base_url = "https://westeurope.api.cognitive.microsoft.com/vision/v2.0/"

analyze_url = vision_base_url + "analyze"

# %% [markdown]
# ## Exemples

# %%
image_url = "https://i.ytimg.com/vi/peAlla42VCw/maxresdefault.jpg"

# %%
headers = {'Ocp-Apim-Subscription-Key': subscription_key }
params  = {'visualFeatures': 'Categories,Description,Color'}
data    = {'url': image_url}
response = requests.post(analyze_url, headers=headers, params=params, json=data)
response.raise_for_status()

analysis = response.json()
print(json.dumps(response.json()))
image_caption = analysis["description"]["captions"][0]["text"].capitalize()
# Out:
# {"categories": [{"name": "others_", "score": 0.078125}, {"name": "outdoor_", "score": 0.00390625, "detail": {"landmarks": []}}], "color": {"dominantColorForeground": "White", "dominantColorBackground": "Black", "dominantColors": ["Black", "Grey"], "accentColor": "488365", "isBwImg": false, "isBWImg": false}, "description": {"tags": ["person", "car", "man", "looking", "truck", "uniform", "sitting", "wearing", "standing", "holding", "bus", "seat", "people", "woman", "riding", "driving", "train"], "captions": [{"text": "a man driving a car", "confidence": 0.8481579845941087}]}, "requestId": "b350d405-cc04-4850-8d6d-0b064e870437", "metadata": {"width": 1280, "height": 720, "format": "Jpeg"}}

# %%
image = Image.open(BytesIO(requests.get(image_url).content))
plt.imshow(image)
plt.axis("off")
_ = plt.title(image_caption, size="x-large", y=-0.1)
plt.show()

# %%
vision_base_url = "https://westeurope.api.cognitive.microsoft.com/vision/v2.0/"
analyze_url = vision_base_url + "analyze"

image_url = "http://assets.nydailynews.com/polopoly_fs/1.2431146.1447262209!/img/httpImage/image.jpg_gen/derivatives/article_750/01n-15-arve-g2118-004.jpg"

# %%
headers = {'Ocp-Apim-Subscription-Key': subscription_key }
params  = {'visualFeatures': 'Categories,Description,Color'}
data    = {'url': image_url}
response = requests.post(analyze_url, headers=headers, params=params, json=data)
response.raise_for_status()

# The 'analysis' object contains various fields that describe the image. The most
# relevant caption for the image is obtained from the 'description' property.
analysis = response.json()
print(json.dumps(response.json()))
image_caption = analysis["description"]["captions"][0]["text"].capitalize()


# Display the image and overlay it with the caption.
image = Image.open(BytesIO(requests.get(image_url).content))
plt.imshow(image)
plt.axis("off")
_ = plt.title(image_caption, size="x-large", y=-0.1)
plt.show()
# Out:
# {"categories": [{"name": "others_", "score": 0.1328125}], "color": {"dominantColorForeground": "White", "dominantColorBackground": "White", "dominantColors": ["White", "Grey"], "accentColor": "666666", "isBwImg": true, "isBWImg": true}, "description": {"tags": ["text", "man", "photo", "standing", "looking", "sign", "people"], "captions": [{"text": "Lee Harvey Oswald looking at the camera", "confidence": 0.7099395763995104}]}, "requestId": "ab7b56a0-027c-4845-85e1-9ef927d63770", "metadata": {"width": 750, "height": 464, "format": "Jpeg"}}

# %%
vision_base_url = "https://westeurope.api.cognitive.microsoft.com/vision/v2.0/"
analyze_url = vision_base_url + "analyze"

image_url = "https://www.francetourisme.fr/media/Visite_tour_eiffel/visite_tour_eiffel_1.jpg"

# %%
headers = {'Ocp-Apim-Subscription-Key': subscription_key }
params  = {'visualFeatures': 'Categories,Description,Color'}
data    = {'url': image_url}
response = requests.post(analyze_url, headers=headers, params=params, json=data)
response.raise_for_status()

# The 'analysis' object contains various fields that describe the image. The most
# relevant caption for the image is obtained from the 'description' property.
analysis = response.json()
print(json.dumps(response.json()))
image_caption = analysis["description"]["captions"][0]["text"].capitalize()


# Display the image and overlay it with the caption.
image = Image.open(BytesIO(requests.get(image_url).content))
plt.imshow(image)
plt.axis("off")
_ = plt.title(image_caption, size="x-large", y=-0.1)
plt.show()
# Out:
# {"categories": [{"name": "building_", "score": 0.8515625, "detail": {"landmarks": [{"name": "Eiffel Tower", "confidence": 0.9843137264251709}]}}, {"name": "outdoor_", "score": 0.00390625, "detail": {"landmarks": [{"name": "Eiffel Tower", "confidence": 0.9843137264251709}]}}], "color": {"dominantColorForeground": "Brown", "dominantColorBackground": "White", "dominantColors": ["White"], "accentColor": "AD781E", "isBwImg": false, "isBWImg": false}, "description": {"tags": ["outdoor", "building", "city", "large", "water", "tower", "view", "clock", "river", "mountain", "harbor", "field", "boat", "body", "lake", "tall", "old", "hill", "ocean", "bridge", "grazing", "train"], "captions": [{"text": "the tower of the city with Eiffel Tower in the background", "confidence": 0.9633965032986773}]}, "requestId": "7a7856d9-e587-442c-ab3f-3dacddc44a20", "metadata": {"width": 1200, "height": 900, "format": "Jpeg"}}

# %%
vision_base_url = "https://westeurope.api.cognitive.microsoft.com/vision/v2.0/"
analyze_url = vision_base_url + "analyze"

image_url = "https://www.autocar.co.nz/_Reviews/Bikes/Street-Triple-765-R/Triumph-Street-Triple-765-R-HEADER.jpg"

# %%
headers = {'Ocp-Apim-Subscription-Key': subscription_key }
params  = {'visualFeatures': 'Categories,Description,Color'}
data    = {'url': image_url}
response = requests.post(analyze_url, headers=headers, params=params, json=data)
response.raise_for_status()

# The 'analysis' object contains various fields that describe the image. The most
# relevant caption for the image is obtained from the 'description' property.
analysis = response.json()
print(json.dumps(response.json()))
image_caption = analysis["description"]["captions"][0]["text"].capitalize()

# Display the image and overlay it with the caption.
image = Image.open(BytesIO(requests.get(image_url).content))
plt.imshow(image)
plt.axis("off")
_ = plt.title(image_caption, size="x-large", y=-0.1)
plt.show()
# Out:
# {"categories": [{"name": "trans_bicycle", "score": 0.99609375}], "color": {"dominantColorForeground": "Black", "dominantColorBackground": "Green", "dominantColors": ["Green", "Black"], "accentColor": "8A5841", "isBwImg": false, "isBWImg": false}, "description": {"tags": ["outdoor", "grass", "motorcycle", "road", "parked", "bicycle", "sitting", "street", "front", "sidewalk", "riding", "side", "park", "man", "helmet", "standing", "city", "blue"], "captions": [{"text": "a motorcycle parked on the side of a road", "confidence": 0.9561071310265764}]}, "requestId": "107e4cb3-7baf-4cad-9ff7-92b07a9757a1", "metadata": {"width": 1400, "height": 788, "format": "Jpeg"}}

# %%
vision_base_url = "https://westeurope.api.cognitive.microsoft.com/vision/v2.0/"
analyze_url = vision_base_url + "analyze"

image_url = "https://thumbs.dreamstime.com/b/people-swimming-pool-20448581.jpg"

# %%
headers = {'Ocp-Apim-Subscription-Key': subscription_key }
params  = {'visualFeatures': 'Categories,Description,Color'}
data    = {'url': image_url}
response = requests.post(analyze_url, headers=headers, params=params, json=data)
response.raise_for_status()

# The 'analysis' object contains various fields that describe the image. The most
# relevant caption for the image is obtained from the 'description' property.
analysis = response.json()
print(json.dumps(response.json()))
image_caption = analysis["description"]["captions"][0]["text"].capitalize()

# Display the image and overlay it with the caption.
image = Image.open(BytesIO(requests.get(image_url).content))
plt.imshow(image)
plt.axis("off")
_ = plt.title(image_caption, size="x-large", y=-0.1)
plt.show()
# Out:
# {"categories": [{"name": "people_swimming", "score": 0.96484375, "detail": {"celebrities": []}}], "color": {"dominantColorForeground": "White", "dominantColorBackground": "Blue", "dominantColors": ["Blue", "White"], "accentColor": "0CA9BF", "isBwImg": false, "isBWImg": false}, "description": {"tags": ["water", "sport", "pool", "outdoor", "swimming", "game", "riding", "ocean", "man", "blue", "playing", "lake", "boy", "young", "people", "body", "woman", "doing", "boat", "skiing", "beach", "board", "jumping", "dog", "standing", "air", "group", "trick", "wave"], "captions": [{"text": "a group of people swimming in a pool of water", "confidence": 0.8895769175428402}]}, "requestId": "eb24957d-e69c-477e-b7c3-73a5f4656052", "metadata": {"width": 800, "height": 533, "format": "Jpeg"}}

# %%
vision_base_url = "https://westeurope.api.cognitive.microsoft.com/vision/v2.0/"

analyze_url = vision_base_url + "analyze"

# Set image_url to the URL of an image that you want to analyze.
image_url = "https://cdn-s3.si.com/s3fs-public/images/Rocky-Balboa-Sylvester-Stallone-Adrian-Talia-Shire-NLC_03462.jpg"

# %%
headers = {'Ocp-Apim-Subscription-Key': subscription_key }
params  = {'visualFeatures': 'Categories,Description,Color'}
data    = {'url': image_url}
response = requests.post(analyze_url, headers=headers, params=params, json=data)
response.raise_for_status()

# The 'analysis' object contains various fields that describe the image. The most
# relevant caption for the image is obtained from the 'description' property.
analysis = response.json()
print(json.dumps(response.json()))
image_caption = analysis["description"]["captions"][0]["text"].capitalize()


# Display the image and overlay it with the caption.
image = Image.open(BytesIO(requests.get(image_url).content))
plt.imshow(image)
plt.axis("off")
_ = plt.title(image_caption, size="x-large", y=-0.1)
plt.show()
# Out:
# {"categories": [{"name": "people_group", "score": 0.640625, "detail": {"celebrities": [{"name": "Sylvester Stallone", "confidence": 0.9281664490699768, "faceRectangle": {"left": 414, "top": 182, "width": 181, "height": 181}}, {"name": "Talia Shire", "confidence": 0.9841282963752747, "faceRectangle": {"left": 326, "top": 321, "width": 170, "height": 170}}]}}], "color": {"dominantColorForeground": "Yellow", "dominantColorBackground": "Grey", "dominantColors": ["Grey", "Yellow", "Black"], "accentColor": "B6151E", "isBwImg": false, "isBWImg": false}, "description": {"tags": ["person", "wearing", "woman", "holding", "man", "teddy", "posing", "young", "stuffed", "dressed", "bear", "standing", "shirt", "outfit", "neck", "phone"], "captions": [{"text": "Talia Shire, Sylvester Stallone are posing for a picture", "confidence": 0.900565691737085}]}, "requestId": "aeda6d3a-5569-4c47-9283-aab61025c0fe", "metadata": {"width": 867, "height": 920, "format": "Jpeg"}}
